# %%
from tickers import tickers

# %%
ticker = []
ns = [0]

for n in range(1000100):
    try:
        if tickers[0][n] == ',':
            ns.append(n)
            ticker.append(tickers[0][(ns[-2]):n])
    except IndexError as e:
        pass
            
print('leggo')

for n in range(1000100):
    try:
        if ticker[n][:2] == ',\n':
            ticker[n] = ticker[n][2:]
    except IndexError as e:
        pass
print(len(ticker))
# Out:
# leggo
# 3298
